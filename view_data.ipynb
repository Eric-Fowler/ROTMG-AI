# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "./Saved_Data/images.npy"
images = np.load(filename)
print(np.shape(images))
# Out:
# (422, 270, 480, 3)

# %%
plt.figure()
plt.imshow(images[0])
plt.show()
