# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# filename = "./Saved_Data/480x270_60fps_images.npy"
# filename = "./Saved_Data/640x360_60fps_images.npy"
filename = "./Saved_Data/960x540_60fps_images.npy"
# filename = "./Saved_Data/1920x1080_60fps_images.npy"
images = np.load(filename)
print(np.shape(images))
plt.figure(dpi=400)
plt.imshow(images[-10])
plt.show()
# Out:
# (142, 540, 960, 3)
